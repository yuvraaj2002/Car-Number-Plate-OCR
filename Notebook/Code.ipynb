# %% [markdown]
# # Connecting Google drive with colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Importing the dependencies

# %%
# !pip install ultralytics
# !pip install tqdm --upgrade
from tqdm.notebook import tqdm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.9/603.9 kB 10.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Model training
# ![image.png](data:image/png;base64,...)

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.135 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/Number_Plate_YOLOv8/data.yaml epochs=10 imgsz=640 batch=8 project = /content/drive/MyDrive/Number_Plate_YOLOv8/Training_Results name = Number_Plates
# Out:
# Ultralytics YOLOv8.0.135 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
